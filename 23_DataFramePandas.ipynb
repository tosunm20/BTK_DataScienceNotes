# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame # excel gibi yazıyor
# Out:
#           0         1         2
# 0 -0.740671 -0.073330  0.712263
# 1 -0.161865 -1.403721  0.340195
# 2 -0.011672  0.087967 -0.079027
# 3  0.626850  0.252366 -0.171610

# %%
dataFrame[0] # sütun olarak getiriyor (cols)
# Out:
# 0   -0.740671
# 1   -0.161865
# 2   -0.011672
# 3    0.626850
# Name: 0, dtype: float64

# %%
yeniDataFrame = pd.DataFrame(data, index=["Atil","Zeynep","Atlas","Mehmet"],columns=["Maas","Yas","Calisma Saati"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil   -0.740671 -0.073330       0.712263
# Zeynep -0.161865 -1.403721       0.340195
# Atlas  -0.011672  0.087967      -0.079027
# Mehmet  0.626850  0.252366      -0.171610

# %%
yeniDataFrame["Yas"]
# Out:
# Atil     -0.073330
# Zeynep   -1.403721
# Atlas     0.087967
# Mehmet    0.252366
# Name: Yas, dtype: float64

# %%
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Atil   -0.740671 -0.073330
# Zeynep -0.161865 -1.403721
# Atlas  -0.011672  0.087967
# Mehmet  0.626850  0.252366

# %%
yeniDataFrame.loc["Atil"] # rowdan çekmek için loc (locate) etmelisin
# Out:
# Maas            -0.740671
# Yas             -0.073330
# Calisma Saati    0.712263
# Name: Atil, dtype: float64

# %%
yeniDataFrame.loc[["Atil","Zeynep"]]
# Out:
#             Maas       Yas  Calisma Saati
# Atil   -0.740671 -0.073330       0.712263
# Zeynep -0.161865 -1.403721       0.340195

# %%
yeniDataFrame.iloc[0] # iloc (index location) Atil'in index 0 olduğundan Atili getirdi
# Out:
# Maas            -0.740671
# Yas             -0.073330
# Calisma Saati    0.712263
# Name: Atil, dtype: float64

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]
#yeni col ekleme

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis = 1) # y = axis = 1, x = axis = 0
# Out:
#             Maas       Yas  Calisma Saati
# Atil   -0.740671 -0.073330       0.712263
# Zeynep -0.161865 -1.403721       0.340195
# Atlas  -0.011672  0.087967      -0.079027
# Mehmet  0.626850  0.252366      -0.171610

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis = 1, inplace = True)
# inplace true olursa ana DataFrame'de de droplanır.

# %%
yeniDataFrame.loc["Atil"]["Calisma Saati"]
# Out:
# 0.7122634904864581

# %%
yeniDataFrame.loc["Atlas","Yas"]
# Out:
# 0.08796685714040683

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil   -0.740671 -0.073330       0.712263
# Zeynep -0.161865 -1.403721       0.340195
# Atlas  -0.011672  0.087967      -0.079027
# Mehmet  0.626850  0.252366      -0.171610

# %%
booleanFrame = yeniDataFrame < 0

# %%
booleanFrame
# Out:
#          Maas    Yas  Calisma Saati
# Atil     True   True          False
# Zeynep   True   True          False
# Atlas    True  False           True
# Mehmet  False  False           True

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil   -0.740671 -0.073330       0.712263
# Zeynep -0.161865 -1.403721       0.340195
# Atlas  -0.011672  0.087967      -0.079027
# Mehmet  0.626850  0.252366      -0.171610

# %%
yeniDataFrame[booleanFrame]
# Out:
#              Maas  Yas  Calisma Saati
# Yeni Indeks
# Ati           NaN  NaN            NaN
# Zey           NaN  NaN            NaN
# Atl           NaN  NaN            NaN
# Meh           NaN  NaN            NaN

# %%
yeniDataFrame[yeniDataFrame["Yas"] > 0] # yası 0 dan büyük olanların bilgilerini bastırır
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Atl         -0.011672  0.087967      -0.079027
# Meh          0.626850  0.252366      -0.171610

# %%
yeniIndeksListesi = ["Ati", "Zey", "Atl", "Meh"]

# %%
yeniDataFrame["Yeni Indeks"] = yeniIndeksListesi # yeni indeks ekleme

# %%
yeniDataFrame
# Out:
#                  Maas       Yas  Calisma Saati Yeni Indeks
# Yeni Indeks
# Ati         -0.740671 -0.073330       0.712263         Ati
# Zey         -0.161865 -1.403721       0.340195         Zey
# Atl         -0.011672  0.087967      -0.079027         Atl
# Meh          0.626850  0.252366      -0.171610         Meh

# %%
yeniDataFrame.set_index("Yeni Indeks", inplace=True)

# %%
yeniDataFrame
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Ati         -0.740671 -0.073330       0.712263
# Zey         -0.161865 -1.403721       0.340195
# Atl         -0.011672  0.087967      -0.079027
# Meh          0.626850  0.252366      -0.171610

# %%
#exeldeki gibi merge etmek
dısIndeksler = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
icIndeksler = ["Homer", "Bart", "Marge", "Cartman", "Kenny", "Kyle"]

# %%
birlesmisIndeks = list(zip(dısIndeksler,icIndeksler))

# %%
birlesmisIndeks
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
birlesmisIndeks = pd.MultiIndex.from_tuples(birlesmisIndeks)

# %%
birlesmisIndeks
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
benimCizgiFilmListem =[[40,"A"],[10,"B"],[30,"C"],[9,"D"],[10,"E"],[11,"F"]]

# %%
benimCizgiFilmListem
# Out:
# [[40, 'A'], [10, 'B'], [30, 'C'], [9, 'D'], [10, 'E'], [11, 'F']]

# %%
cizgiFilmNumpyDizisi = np.array(benimCizgiFilmListem)

# %%
cizgiFilmNumpyDizisi
# Out:
# array([['40', 'A'],
#        ['10', 'B'],
#        ['30', 'C'],
#        ['9', 'D'],
#        ['10', 'E'],
#        ['11', 'F']], dtype='<U11')

# %%
cizgiFilmDataFrame = pd.DataFrame(data=cizgiFilmNumpyDizisi,index=birlesmisIndeks,columns=["Yas","Meslek"])

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F

# %%
cizgiFilmDataFrame.loc["Simpson"]
# Out:
#       Yas Meslek
# Homer  40      A
# Bart   10      B
# Marge  30      C

# %%
cizgiFilmDataFrame.loc["Simpson","Homer"]
# Out:
# Yas       40
# Meslek     A
# Name: (Simpson, Homer), dtype: object

# %%
cizgiFilmDataFrame.loc["Simpson"].loc["Homer"]
# Out:
# Yas       40
# Meslek     A
# Name: Homer, dtype: object

# %%
cizgiFilmDataFrame.index.names = ["Film Adı", "Karakter"]

# %%
cizgiFilmDataFrame
# Out:
#                     Yas Meslek
# Film Adı   Karakter
# Simpson    Homer     40      A
#            Bart      10      B
#            Marge     30      C
# South Park Cartman    9      D
#            Kenny     10      E
#            Kyle      11      F
