# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Serise / Seriler

# %%
benimSozlugum = {"Atil" : 50, "Zeynep" : 40, "Mehmet" : 30}

# %%
pd.Series(benimSozlugum)
# Out:
# Atil      50
# Zeynep    40
# Mehmet    30
# dtype: int64

# %%
benimYaslarim = [50,40,30]
benimIsimlerim = ["Atil", "Zeynep", "Mustafa"]

# %%
pd.Series(benimYaslarim) # 0, 1, 2'yi otomatik atadı.
# Out:
# 0    50
# 1    40
# 2    30
# dtype: int64

# %%
pd.Series(benimYaslarim,benimIsimlerim) 
# data=benimYaslarim, index=benimIslerim
# Out:
# Atil       50
# Zeynep     40
# Mustafa    30
# dtype: int64

# %%
numpyDizisi = np.array([50,40,30])

# %%
pd.Series(data=benimYaslarim, index=benimIsimlerim)
# Out:
# Atil       50
# Zeynep     40
# Mustafa    30
# dtype: int64

# %%
pd.Series(["Mustafa", "Ahmet", "Mehmet"], [1,2,3])
# Out:
# 1    Mustafa
# 2      Ahmet
# 3     Mehmet
# dtype: object

# %%
yarismaSonucu1 = pd.Series([10,5,1],["Atil","Atlas","Osman"])

# %%
yarismaSonucu2 = pd.Series([20,10,8],["Atil","Atlas","Osman"])

# %%
yarismaSonucu2["Atlas"]
# Out:
# 10

# %%
sonSonuc = yarismaSonucu1 + yarismaSonucu2

# %%
sonSonuc # keywordu aynı olanları toplar # aynı index olmasa bile problem çökmez
# Out:
# Atil     40
# Atlas    20
# Osman    16
# dtype: int64

# %%
farkliSeries = pd.Series([20,30,40,50],["a","b","c","d"])
farkliSeries2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
sonSonuc2 = farkliSeries + farkliSeries2

# %%
sonSonuc2 # kesişenleri toplar
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
