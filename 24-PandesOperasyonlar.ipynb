# %%
import pandas as pd
import numpy as np

# %%
sozlukVerisi = {"Istanbul" : [30,29,np.nan], "Ankara" : [20,np.nan,25], "Izmir": [40,39,38]}
havaDurumuDataFrame = pd.DataFrame(sozlukVerisi)

# %%
havaDurumuDataFrame
# Out:
#    Istanbul  Ankara  Izmir
# 0      30.0    20.0     40
# 1      29.0     NaN     39
# 2       NaN    25.0     38

# %%
havaDurumuDataFrame.dropna() # NaN varsa komple satırı çıkarır
# Out:
#    Istanbul  Ankara  Izmir
# 0      30.0    20.0     40

# %%
havaDurumuDataFrame.dropna(axis=1)
# Out:
#    Izmir
# 0     40
# 1     39
# 2     38

# %%
yeniVeri = {"Istanbul" : [30,29,np.nan], "Ankara" : [20,np.nan,25], "Izmir": [40,39,38], "Antalya": [40,np.nan,np.nan]}
yeniDataFrame = pd.DataFrame(yeniVeri)

# %%
yeniDataFrame
# Out:
#    Istanbul  Ankara  Izmir  Antalya
# 0      30.0    20.0     40     40.0
# 1      29.0     NaN     39      NaN
# 2       NaN    25.0     38      NaN

# %%
yeniDataFrame.dropna(axis=1,thresh=2)
# thresh=x, x ve üzeri nan olanları atar
# Out:
#    Istanbul  Ankara  Izmir
# 0      30.0    20.0     40
# 1      29.0     NaN     39
# 2       NaN    25.0     38

# %%
yeniDataFrame.fillna(20)
# Out:
#    Istanbul  Ankara  Izmir  Antalya
# 0      30.0    20.0     40     40.0
# 1      29.0     NaN     39      NaN
# 2       NaN    25.0     38      NaN

# %% [markdown]
# ## groupby

# %%
maasSozlugu = {"Departman" : ["Yazılım", "Satış", "Pazarlama", "Finans", "İnsan Kaynakları","Hukuk"],
              "Çalışan İsmi" : ["Ahmet", "Mehmet","Atil","Burak","Zeynep","Fatma"],
               "Maas" : [100,150,200,300,400,500]
              }

# %%
maasDataFrame = pd.DataFrame(maasSozlugu)

# %%
maasDataFrame
# Out:
#           Departman Çalışan İsmi  Maas
# 0           Yazılım        Ahmet   100
# 1             Satış       Mehmet   150
# 2         Pazarlama         Atil   200
# 3            Finans        Burak   300
# 4  İnsan Kaynakları       Zeynep   400
# 5             Hukuk        Fatma   500

# %%
grupObjesi = maasDataFrame.groupby("Departman")

# %%
grupObjesi.count()
# Out:
#                   Çalışan İsmi  Maas
# Departman
# Finans                       1     1
# Hukuk                        1     1
# Pazarlama                    1     1
# Satış                        1     1
# Yazılım                      1     1
# İnsan Kaynakları             1     1

# %%
grupObjesi.mean()
# Out:
#                   Maas
# Departman
# Finans             300
# Hukuk              500
# Pazarlama          200
# Satış              150
# Yazılım            100
# İnsan Kaynakları   400

# %%
grupObjesi.describe()
# Out:
#                   Maas
#                  count   mean std    min    25%    50%    75%    max
# Departman
# Finans             1.0  300.0 NaN  300.0  300.0  300.0  300.0  300.0
# Hukuk              1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# Pazarlama          1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# Satış              1.0  150.0 NaN  150.0  150.0  150.0  150.0  150.0
# Yazılım            1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# İnsan Kaynakları   1.0  400.0 NaN  400.0  400.0  400.0  400.0  400.0
